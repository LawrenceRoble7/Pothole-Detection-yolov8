# %%
# Mount your gdrive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Thesis/PotholeDetectionTraining
# Out:
# /content/gdrive/MyDrive/Thesis/PotholeDetectionTraining

# %%
# %ls
# Out:
# Potholes-Detector-23/  PotholeTraining.ipynb

# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 18.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ryOAX7HvyFsFUvA2iPyR")
project = rf.workspace("cebu-technological-university-x8psq").project("potholes-detector-dkioe")
version = project.version(23)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.28, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Potholes-Detector-23 in yolov8:: 100%|██████████| 10502/10502 [01:01<00:00, 169.85it/s]

# %%
ROOT_DIR = '/content/gdrive/MyDrive/Thesis/PotholeDetectionTraining/Potholes-Detector-23'

# %%
import os
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8n.pt")  # build a new model from scratch n s m l xl
model = YOLO("yolov8n.pt")

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=500, single_cls=True)  # train the model
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
